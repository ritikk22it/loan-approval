# %% [markdown]
# <a href="https://colab.research.google.com/github/ritikk22it/loan-approval/blob/main/practical%20no%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.DataFrame({"roll no":[1,2,3,2],
                 "Name":['sandeep','ritik','nirjala','ritik'],
                 "Marks":[98,90,80,90]
                 })

# %%
print(df)
# Out:
#    roll no     Name  Marks
# 0        1  sandeep     98
# 1        2    ritik     90
# 2        3  nirjala     80
# 3        4   prasad     99

# %%
df.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of    roll no   Name  Marks
# 0    False  False  False
# 1    False  False  False
# 2    False  False  False
# 3    False  False  False>

# %%
df.describe()
# Out:
#         roll no     Marks
# count  4.000000   4.00000
# mean   2.500000  91.75000
# std    1.290994   8.80814
# min    1.000000  80.00000
# 25%    1.750000  87.50000
# 50%    2.500000  94.00000
# 75%    3.250000  98.25000
# max    4.000000  99.00000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['roll no'].plot(kind='hist', bins=20, title='roll no')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Marks'].plot(kind='hist', bins=20, title='Marks')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='roll no', y='Marks', s=32, alpha=.8)
# ...

# %%
df.describe(include="object")
# Out:
#            Name
# count         4
# unique        4
# top     sandeep
# freq          1

# %%
df.shape
# Out:
# (4, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   roll no  4 non-null      int64
#  1   Name     4 non-null      object
#  2   Marks    4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 224.0+ bytes

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.nunique()
# Out:
# roll no    3
# Name       3
# Marks      3
# dtype: int64

# %%
df.value_counts()
# Out:
# roll no  Name     Marks
# 2        ritik    90       2
# 1        sandeep  98       1
# 3        nirjala  80       1
# dtype: int64

# %%
df["roll no"].value_counts()
# Out:
# 2    2
# 1    1
# 3    1
# Name: roll no, dtype: int64

# %%
data=df.corr()
# Out:
# <ipython-input-40-1aa37458716e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data=df.corr()

# %%
cor=df.corr()
import seaborn as sns
sns.heatmap(cor,annot=True,fmt=".3f",cmap='coolwarm')
# Out:
# <ipython-input-56-4d2567ab6530>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor=df.corr()
# <Axes: >

# %%
df.var()
# Out:
# <ipython-input-57-28ded241fd7c>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# roll no     0.666667
# Marks      54.333333
# dtype: float64

# %%
df.mean()
# Out:
# <ipython-input-59-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# roll no     2.0
# Marks      89.5
# dtype: float64

# %%
df.min()
# Out:
# roll no          1
# Name       nirjala
# Marks           80
# dtype: object

# %%
df['roll no'].var()
# Out:
# 0.6666666666666666

# %%
df.cov()
# Out:
# <ipython-input-67-6f98a29763d5>:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.cov()
#           roll no      Marks
# roll no  0.666667  -6.000000
# Marks   -6.000000  54.333333
